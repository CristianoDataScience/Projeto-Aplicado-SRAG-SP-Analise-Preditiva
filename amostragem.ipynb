# %% [markdown]
# <a href="https://colab.research.google.com/github/CristianoDataScience/Projeto-Aplicado-SRAG-SP-Analise-Preditiva/blob/main/amostragem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importando Bibliotecas

# %%
import pandas as pd 
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Base de dados

# %%
df_sp = pd.read_csv('/content/drive/MyDrive/Projeto_Aplicado_SRAG/base_dados_srag_sp.csv',
                    sep=',', encoding='iso-8859-1')
# encoding: codificação de caracteres, normalmente utiliza-se o iso-8859-1, utf-8, latin-1)
df_sp.head()
# Out:
#          data      minicipio  idade       sexo      srag evolucao  \
# 0  2023-02-10        UBATUBA     55    Feminio  Covid-19     Cura
# 1  2021-02-22      SAO PAULO     40  Masculino  Covid-19     Cura
# 2  2020-11-13      SAO PAULO     65    Feminio  Covid-19     Cura
# 3  2021-02-10      SAO PAULO     25    Feminio  Covid-19     Cura
# 4  2021-02-18  GUARATINGUETA     75  Masculino  Covid-19     Cura
#
#    qtde_masculino  qtde_feminino  total
# 0               0              1      1
# 1               7              0      7
# 2               0              1      1
# 3               0              2      2
# 4               1              0      1

# %%
#renomendo as linhas 
df_sp['sexo'] = df_sp['sexo'].replace({'Masculino': 'M', 'Feminio': 'F'})
df_sp
# Out:
#               data        minicipio  idade sexo         srag evolucao  \
# 0       2023-02-10          UBATUBA     55    F     Covid-19     Cura
# 1       2021-02-22        SAO PAULO     40    M     Covid-19     Cura
# 2       2020-11-13        SAO PAULO     65    F     Covid-19     Cura
# 3       2021-02-10        SAO PAULO     25    F     Covid-19     Cura
# 4       2021-02-18    GUARATINGUETA     75    M     Covid-19     Cura
# ...            ...              ...    ...  ...          ...      ...
# 857826  2020-06-01          DIADEMA     55    M     Covid-19     Cura
# 857827  2020-06-02          ITAPEVI     55    M     Covid-19     Cura
# 857828  2020-04-16        SAO PAULO     60    M  Outras SRAG    Óbito
# 857829  2020-06-05       PIRACICABA     45    F     Covid-19     Cura
# 857830  2021-11-24  TABOAO DA SERRA     70    M     Covid-19     Cura
#
#         qtde_masculino  qtde_feminino  total
# 0                    0              1      1
# 1                    7              0      7
# 2                    0              1      1
# 3                    0              2      2
# 4                    1              0      1
# ...                ...            ...    ...
# 857826               1              0      1
# 857827               1              0      1
# 857828               1              0      1
# 857829               0              1      1
# 857830               1              0      1
#
# [857831 rows x 9 columns]

# %% [markdown]
# ## Base de Dados apenas Síndrome Respiratória Aguda Grave (SRAG)

# %%
df_sp = df_sp[df_sp['srag'] != 'Covid-19']
df_sp = df_sp.rename(columns={'minicipio': 'municipio', 'idade': 'faixa_etaria'})
df_sp
# Out:
#               data              municipio  faixa_etaria sexo         srag  \
# 5       2023-02-09              SAO PAULO            10    F  Outras SRAG
# 6       2023-02-24              SAO PAULO            10    M  Outras SRAG
# 7       2021-08-13      BRAGANCA PAULISTA            10    F  Outras SRAG
# 8       2023-02-19           PRAIA GRANDE            10    F  Outras SRAG
# 9       2023-02-22  SAO JOSE DO RIO PRETO            20    F  Outras SRAG
# ...            ...                    ...           ...  ...          ...
# 857818  2021-09-21              SAO PAULO            50    M  Outras SRAG
# 857821  2021-03-02  SAO JOSE DO RIO PRETO            50    M  Outras SRAG
# 857822  2020-07-24               CAMPINAS            80    M  Outras SRAG
# 857823  2020-07-20        MOGI DAS CRUZES            45    M  Outras SRAG
# 857828  2020-04-16              SAO PAULO            60    M  Outras SRAG
#
#             evolucao  qtde_masculino  qtde_feminino  total
# 5               Cura               0              1      1
# 6       Em Avaliação               1              0      1
# 7               Cura               0              1      1
# 8       Em Avaliação               0              1      1
# 9               Cura               0              1      1
# ...              ...             ...            ...    ...
# 857818          Cura               1              0      1
# 857821         Óbito               1              0      1
# 857822          Cura               1              0      1
# 857823         Óbito               1              0      1
# 857828         Óbito               1              0      1
#
# [344875 rows x 9 columns]

# %%
#Analisando quantidade de casos por idade 
df_sp['faixa_etaria'].value_counts().sort_index()
# Out:
# 0      44349
# 5      25534
# 10     10661
# 15      5085
# 20      7579
# 25      8980
# 30     10654
# 35     12719
# 40     13841
# 45     14988
# 50     17134
# 55     20402
# 60     23118
# 65     24997
# 70     25343
# 75     24121
# 80     22408
# 85     17887
# 90     10871
# 95      3591
# 100      566
# 105       45
# 110        1
# 115        1
# Name: faixa_etaria, dtype: int64

# %%
#Análise estatística
df_sp.describe()
# Out:
#               idade  qtde_masculino  qtde_feminino          total
# count  344875.00000   344875.000000  344875.000000  344875.000000
# mean       46.24116        0.597524       0.560206       1.157796
# std        29.70297        0.752596       0.718363       0.642560
# min         0.00000        0.000000       0.000000       1.000000
# 25%        20.00000        0.000000       0.000000       1.000000
# 50%        55.00000        1.000000       0.000000       1.000000
# 75%        70.00000        1.000000       1.000000       1.000000
# max       115.00000       34.000000      28.000000      34.000000

# %%
df_sp['total'].value_counts().sort_index()
# Out:
# 1     311613
# 2      22798
# 3       5760
# 4       2297
# 5       1067
# 6        540
# 7        306
# 8        180
# 9        113
# 10        62
# 11        52
# 12        26
# 13        20
# 14        14
# 15         9
# 16         3
# 17         5
# 18         3
# 19         2
# 20         2
# 22         1
# 28         1
# 34         1
# Name: total, dtype: int64

# %% [markdown]
# ## Analisando casos de 0 há 15 anos por municipio

# %%
menores_de_15 = df_sp.query('faixa_etaria <= 15')['municipio'].value_counts()

# %%
menores_de_15
# Out:
# SAO PAULO              19954
# GUARULHOS               6853
# CAMPINAS                5133
# SAO JOSE DOS CAMPOS     1793
# DIADEMA                 1783
#                        ...
# GLICERIO                   1
# ITAPIRAPUA PAULISTA        1
# BARRA DO CHAPEU            1
# TAIUVA                     1
# CAFELANDIA                 1
# Name: municipio, Length: 608, dtype: int64

# %%
df_sp_maiores = df_sp.loc[df_sp.faixa_etaria > 15]
df_sp_maiores
# Out:
#               data              municipio  faixa_etaria sexo         srag  \
# 9       2023-02-22  SAO JOSE DO RIO PRETO            20    F  Outras SRAG
# 13      2023-02-20                DIADEMA            85    M  Outras SRAG
# 16      2022-11-28      BRAGANCA PAULISTA            90    F  Outras SRAG
# 17      2023-02-21              SAO PAULO            50    M  Outras SRAG
# 19      2023-02-27              SAO PAULO            40    M  Outras SRAG
# ...            ...                    ...           ...  ...          ...
# 857818  2021-09-21              SAO PAULO            50    M  Outras SRAG
# 857821  2021-03-02  SAO JOSE DO RIO PRETO            50    M  Outras SRAG
# 857822  2020-07-24               CAMPINAS            80    M  Outras SRAG
# 857823  2020-07-20        MOGI DAS CRUZES            45    M  Outras SRAG
# 857828  2020-04-16              SAO PAULO            60    M  Outras SRAG
#
#             evolucao  qtde_masculino  qtde_feminino  total
# 9               Cura               0              1      1
# 13             Óbito               1              0      1
# 16              Cura               0              2      2
# 17      Em Avaliação               1              0      1
# 19      Em Avaliação               1              0      1
# ...              ...             ...            ...    ...
# 857818          Cura               1              0      1
# 857821         Óbito               1              0      1
# 857822          Cura               1              0      1
# 857823         Óbito               1              0      1
# 857828         Óbito               1              0      1
#
# [259246 rows x 9 columns]

# %% [markdown]
# ## AMOSTRAGEM ALEATÓRIA SIMPLES

# %%
np.random.seed(1)

# %%
amos_simples = df_sp_maiores.sample(frac=0.20) # Percentual

# %%
amos_simples
# Out:
#               data            municipio  faixa_etaria sexo         srag  \
# 504179  2020-12-07               SANTOS            70    F  Outras SRAG
# 524645  2022-07-27  PRESIDENTE PRUDENTE            75    F  Outras SRAG
# 545119  2021-02-06      TABOAO DA SERRA            40    M  Outras SRAG
# 163930  2021-05-10            SAO PAULO            80    F  Outras SRAG
# 433336  2020-11-04            SAO PAULO            50    M  Outras SRAG
# ...            ...                  ...           ...  ...          ...
# 269548  2020-09-10            GUARULHOS            60    F  Outras SRAG
# 541551  2020-04-13            SAO PAULO            60    M  Outras SRAG
# 540492  2022-09-22            SAO PAULO            30    M  Outras SRAG
# 265681  2022-01-11             SOROCABA            50    M  Outras SRAG
# 93501   2022-09-08             PAULINIA            75    M  Outras SRAG
#
#             evolucao  qtde_masculino  qtde_feminino  total
# 504179  Em Avaliação               0              1      1
# 524645  Em Avaliação               0              1      1
# 545119          Cura               1              0      1
# 163930  Em Avaliação               0              1      1
# 433336         Óbito               1              0      1
# ...              ...             ...            ...    ...
# 269548          Cura               0              1      1
# 541551          Cura               1              0      1
# 540492          Cura               1              0      1
# 265681         Óbito               1              0      1
# 93501           Cura               1              0      1
#
# [51849 rows x 9 columns]
